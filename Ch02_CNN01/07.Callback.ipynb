# %% [markdown]
# # Callbacks

# %% [markdown]
# ## 模型

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

# 載入 MNIST 手寫阿拉伯數字資料
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# 特徵縮放，使用常態化(Normalization)，公式 = (x - min) / (max - min)
x_train_norm, x_test_norm = x_train / 255.0, x_test / 255.0

# 建立模型
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# 設定優化器(optimizer)、損失函數(loss)、效能衡量指標(metrics)的類別
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# c:\Users\ELSA\anaconda3\envs\PyIII_12\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## EarlyStopping callbacks

# %%
# validation loss 三個執行週期沒改善就停止訓練
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, monitor = 'val_accuracy'),
]

# %%
# 訓練 20 次，但實際只訓練 12次就停止了
history = model.fit(x_train_norm, y_train, epochs=20, validation_split=0.2,
                    callbacks=my_callbacks)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8683 - loss: 0.4531 - val_accuracy: 0.9582 - val_loss: 0.1459
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9594 - loss: 0.1328 - val_accuracy: 0.9700 - val_loss: 0.1049
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9712 - loss: 0.0926 - val_accuracy: 0.9750 - val_loss: 0.0842
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9790 - loss: 0.0681 - val_accuracy: 0.9750 - val_loss: 0.0826
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9826 - loss: 0.0542 - val_accuracy: 0.9742 - val_loss: 0.0811
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9863 - loss: 0.0435 - val_accuracy: 0.9763 - val_loss: 0.0774
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9866 - loss: 0.0397 - val_accuracy: 0.9783 - val_loss: 0.0730
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9901 - loss: 0.0317 - val_accuracy: 0.9772 - val_loss: 0.0806
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9902 - loss: 0.0303 - val_accuracy: 0.9779 - val_loss: 0.0803
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9904 - loss: 0.0274 - val_accuracy: 0.9786 - val_loss: 0.0777
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0222 - val_accuracy: 0.9802 - val_loss: 0.0786
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0213 - val_accuracy: 0.9797 - val_loss: 0.0809
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.0176 - val_accuracy: 0.9785 - val_loss: 0.0863
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0211 - val_accuracy: 0.9806 - val_loss: 0.0779
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9948 - loss: 0.0160 - val_accuracy: 0.9801 - val_loss: 0.0841
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0198 - val_accuracy: 0.9795 - val_loss: 0.0956
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.0148 - val_accuracy: 0.9799 - val_loss: 0.0886

# %%
# 對訓練過程的準確度繪圖
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(1,len(history.history['accuracy'])+1), history.history['accuracy'], 'r', label='accuracy')
plt.plot(np.arange(1,len(history.history['accuracy'])+1), history.history['val_accuracy'], 'g', label='val_accuracy')
plt.legend()

# %% [markdown]
# ## 改為 val_loss

# %%
# validation loss 三個執行週期沒改善就停止訓練
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, monitor = 'val_loss'),
]

# %%
# 訓練 20 次，但實際只訓練 12次就停止了
history = model.fit(x_train_norm, y_train, epochs=20, validation_split=0.2,
                    callbacks=my_callbacks)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - accuracy: 0.9922 - loss: 0.0239 - val_accuracy: 0.9797 - val_loss: 0.0800
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.9922 - loss: 0.0239 - val_accuracy: 0.9787 - val_loss: 0.0849
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9933 - loss: 0.0204 - val_accuracy: 0.9803 - val_loss: 0.0889
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9922 - loss: 0.0237 - val_accuracy: 0.9803 - val_loss: 0.0837

# %%
# 對訓練過程的準確度繪圖
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(1,len(history.history['loss'])+1), history.history['loss'], 'r', label='loss')
plt.plot(np.arange(1,len(history.history['loss'])+1), history.history['val_loss'], 'g', label='val_loss')
plt.xticks(ticks=np.arange(1,len(history.history['loss'])+1))
plt.legend()

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test, verbose=0)
score
# Out:
# [0.07163915038108826, 0.9815000295639038]

# %% [markdown]
# ## ModelCheckpoint callback

# %%
# 定義 ModelCheckpoint callback
checkpoint_filepath = 'd1.weights.h5' 
#checkpoint_filepath = 'model.{epoch:02d}.h5' 
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, # 設定存檔名稱
    save_weights_only=True,       # 只存權重
    monitor='val_accuracy',       # 監看驗證資料的準確率
    mode='max',           # 設定save_best_only=True時，best是指 max or min
    save_best_only=True)          # 只存最好的模型

EPOCHS = 3  # 訓練 3 次
model.fit(x_train_norm, y_train, epochs=EPOCHS, validation_split=0.2, 
          callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9943 - loss: 0.0178 - val_accuracy: 0.9793 - val_loss: 0.0905
# Epoch 2/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9941 - loss: 0.0177 - val_accuracy: 0.9808 - val_loss: 0.0858
# Epoch 3/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9942 - loss: 0.0162 - val_accuracy: 0.9781 - val_loss: 0.0986

# %%
# 再訓練 3 次，觀察 accuracy，會接續上一次，繼續改善 accuracy。
model.fit(x_train_norm, y_train, epochs=EPOCHS, validation_split=0.2,
          callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9938 - loss: 0.0184 - val_accuracy: 0.9802 - val_loss: 0.0863
# Epoch 2/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.9956 - loss: 0.0140 - val_accuracy: 0.9779 - val_loss: 0.1122
# Epoch 3/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9944 - loss: 0.0163 - val_accuracy: 0.9803 - val_loss: 0.0986

# %% [markdown]
# ## TensorBoard callback

# %%
# 可能會出錯,不再更新
# 定義 tensorboard callback
tensorboard_callback = [tf.keras.callbacks.TensorBoard(log_dir='.\\logs',
                       histogram_freq=1)]

# 訓練 5 次
history = model.fit(x_train_norm, y_train, epochs=5, validation_split=0.2,
                    callbacks=tensorboard_callback)

# %%
# 載入 TensorBoard notebook extension，即可在 jupyter notebook 啟動 Tensorboard
# %load_ext tensorboard

# 啟動 Tensorboard
# %tensorboard --logdir ./logs

# %%
# 可同時定義多個Callback事件
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3),
    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]
model.fit(x_train_norm, y_train, epochs=10, callbacks=my_callbacks)
